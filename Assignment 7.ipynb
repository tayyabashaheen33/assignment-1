# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.shape
# Out:
# (25973, 6)

# %%
df.shape[0]
# Out:
# 25973

# %%
df.shape[1]
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experience_coding  25973 non-null  float64
#  1   python_user        25973 non-null  bool
#  2   r_user             25973 non-null  bool
#  3   sql_user           25973 non-null  bool
#  4   most_used          16835 non-null  object
#  5   compensation       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
df.head(10)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.tail(15)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25958                1.3         True    True     False         Keras
# 25959                1.6         True   False      True    TensorFlow
# 25960               17.8         True   False      True       PyTorch
# 25961                3.7         True   False      True       PyTorch
# 25962                1.1         True   False     False    TensorFlow
# 25963               25.4         True   False     False       PyTorch
# 25964                5.9         True   False     False    TensorFlow
# 25965                2.0         True   False      True         Keras
# 25966                1.9         True   False     False  Scikit-learn
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# ...

# %%
df.loc[2]
# Out:
# experience_coding      2.2
# python_user           True
# r_user               False
# sql_user             False
# most_used              NaN
# compensation         74321
# Name: 2, dtype: object

# %%
df.loc[2, 'sql_user']
# Out:
# False

# %%
df.iloc[2]
# Out:
# experience_coding      2.2
# python_user           True
# r_user               False
# sql_user             False
# most_used              NaN
# compensation         74321
# Name: 2, dtype: object

# %%
df.iloc[3,4]
# Out:
# nan

# %%
df.loc[2:10]
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used  \
# 2                 2.2         True   False     False           NaN
# 3                 2.7        False   False      True           NaN
# 4                 1.2         True   False     False  Scikit-learn
# 5                 1.0         True   False     False       PyTorch
# 6                 1.8        False   False     False           NaN
# 7                 6.1         True   False     False    TensorFlow
# 8                 4.5         True   False      True  Scikit-learn
# 9                 1.1         True   False      True    TensorFlow
# 10                2.7         True    True      True           NaN
#
#     compensation
# 2          74321
# 3          62593
# 4          36288
# 5          61302
# 6          68984
# 7          18858
# 8          55418
# 9            614
# 10         70564

# %%
df.iloc[2:10]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.iloc[2:10,:4]
# Out:
#    experience_coding  python_user  r_user  sql_user
# 2                2.2         True   False     False
# 3                2.7        False   False      True
# 4                1.2         True   False     False
# 5                1.0         True   False     False
# 6                1.8        False   False     False
# 7                6.1         True   False     False
# 8                4.5         True   False      True
# 9                1.1         True   False      True

# %%
df.loc[2:9,:'sql_user']
# Out:
#    experience_coding  python_user  r_user  sql_user
# 2                2.2         True   False     False
# 3                2.7        False   False      True
# 4                1.2         True   False     False
# 5                1.0         True   False     False
# 6                1.8        False   False     False
# 7                6.1         True   False     False
# 8                4.5         True   False      True
# 9                1.1         True   False      True

# %%
df1 = pd.read_csv('compensation data.csv',index_col=1)
df1
# Out:
#              experience_coding  r_user  sql_user     most_used  compensation
# python_user
# True                       6.1   False      True  Scikit-learn        124267
# True                      12.3    True      True  Scikit-learn        236889
# True                       2.2   False     False           NaN         74321
# False                      2.7   False      True           NaN         62593
# True                       1.2   False     False  Scikit-learn         36288
# ...                        ...     ...       ...           ...           ...
# True                       1.9   False      True  Scikit-learn         15800
# True                       1.4   False     False       PyTorch         62456
# False                      0.0   False     False           NaN           923
# True                       9.4   False      True  Scikit-learn         60609
# False                      0.0   False     False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df.iloc[[2,10]]
# Out:
#     experience_coding  python_user  r_user  sql_user most_used  compensation
# 2                 2.2         True   False     False       NaN         74321
# 10                2.7         True    True      True       NaN         70564

# %%
df.loc[[2,10,100],['python_user','r_user']]
# Out:
#      python_user  r_user
# 2           True   False
# 10          True    True
# 100        False    True

# %%
df.iloc[[2,10],[1,2]]
# Out:
#     python_user  r_user
# 2          True   False
# 10         True    True

# %%
df['experience_coding']
# Out:
# 0         6.1
# 1        12.3
# 2         2.2
# 3         2.7
# 4         1.2
#          ...
# 25968     1.9
# 25969     1.4
# 25970     0.0
# 25971     9.4
# 25972     0.0
# Name: experience_coding, Length: 25973, dtype: float64

# %%
# pd.options.display.max_rows = None

# %%
df.head(1)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
#
#    compensation
# 0        124267

# %%
df[['python_user','most_used','compensation']]
# Out:
#        python_user     most_used  compensation
# 0             True  Scikit-learn        124267
# 1             True  Scikit-learn        236889
# 2             True           NaN         74321
# 3            False           NaN         62593
# 4             True  Scikit-learn         36288
# ...            ...           ...           ...
# 25968         True  Scikit-learn         15800
# 25969         True       PyTorch         62456
# 25970        False           NaN           923
# 25971         True  Scikit-learn         60609
# 25972        False           NaN           493
#
# [25973 rows x 3 columns]

# %%
df[['python_user','most_used','compensation']].head()
# Out:
#    python_user     most_used  compensation
# 0         True  Scikit-learn        124267
# 1         True  Scikit-learn        236889
# 2         True           NaN         74321
# 3        False           NaN         62593
# 4         True  Scikit-learn         36288

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.drop(25970, inplace = True)
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df2 = pd.read_csv('compensation data.csv',header = None)
df2
# Out:
#                        0            1       2         3             4  \
# 0      experience_coding  python_user  r_user  sql_user     most_used
# 1                    6.1         TRUE   FALSE      TRUE  Scikit-learn
# 2                   12.3         TRUE    TRUE      TRUE  Scikit-learn
# 3                    2.2         TRUE   FALSE     FALSE           NaN
# 4                    2.7        FALSE   FALSE      TRUE           NaN
# ...                  ...          ...     ...       ...           ...
# 25969                1.9         TRUE   FALSE      TRUE  Scikit-learn
# 25970                1.4         TRUE   FALSE     FALSE       PyTorch
# 25971                  0        FALSE   FALSE     FALSE           NaN
# 25972                9.4         TRUE   FALSE      TRUE  Scikit-learn
# 25973                  0        FALSE   FALSE     FALSE           NaN
#
#                   5
# 0      compensation
# 1            124267
# 2            236889
# 3             74321
# ...

# %%
df2 = pd.read_csv('compensation data.csv',header = 1)
df2
# Out:
#         6.1   TRUE  FALSE  TRUE.1  Scikit-learn  124267
# 0      12.3   True   True    True  Scikit-learn  236889
# 1       2.2   True  False   False           NaN   74321
# 2       2.7  False  False    True           NaN   62593
# 3       1.2   True  False   False  Scikit-learn   36288
# 4       1.0   True  False   False       PyTorch   61302
# ...     ...    ...    ...     ...           ...     ...
# 25967   1.9   True  False    True  Scikit-learn   15800
# 25968   1.4   True  False   False       PyTorch   62456
# 25969   0.0  False  False   False           NaN     923
# 25970   9.4   True  False    True  Scikit-learn   60609
# 25971   0.0  False  False   False           NaN     493
#
# [25972 rows x 6 columns]

# %%
df['most_used'] == 'Scikit-learn'
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 25967     True
# 25968     True
# 25969    False
# 25971     True
# 25972    False
# Name: most_used, Length: 25972, dtype: bool

# %%
df[df['most_used'] == 'Scikit-learn']
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                   6.10         True   False      True  Scikit-learn
# 1                  12.30         True    True      True  Scikit-learn
# 4                   1.20         True   False     False  Scikit-learn
# 8                   4.50         True   False      True  Scikit-learn
# 11                  0.93         True    True     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25952               1.40         True   False     False  Scikit-learn
# 25966               1.90         True   False     False  Scikit-learn
# 25967               6.10         True   False      True  Scikit-learn
# 25968               1.90         True   False      True  Scikit-learn
# 25971               9.40         True   False      True  Scikit-learn
#
#        compensation
# 0            124267
# 1            236889
# 4             36288
# 8             55418
# ...

# %%
df[(df['most_used'] == 'Scikit-learn') & (df['python_user'] == 'True')]
# Out:
# Empty DataFrame
# Columns: [experience_coding, python_user, r_user, sql_user, most_used, compensation]
# Index: []

# %%
df['most_used'].unique()
# Out:
# array(['Scikit-learn', nan, 'PyTorch', 'TensorFlow', 'Keras'],
#       dtype=object)

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df[(df['experience_coding'] == 6.1) & (df['python_user'] == True)]
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 7                    6.1         True   False     False    TensorFlow
# 246                  6.1         True   False      True         Keras
# 323                  6.1         True   False      True    TensorFlow
# 765                  6.1         True   False      True  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 24871                6.1         True    True     False  Scikit-learn
# 24952                6.1         True    True      True  Scikit-learn
# 25363                6.1         True    True      True           NaN
# 25546                6.1         True   False      True  Scikit-learn
# 25967                6.1         True   False      True  Scikit-learn
#
#        compensation
# 0            124267
# 7             18858
# 246           32815
# 323           70778
# ...

# %%
df[(df['experience_coding'] == 6.1) | (df['experience_coding'] == 0.0)]
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 7                    6.1         True   False     False    TensorFlow
# 84                   0.0        False   False     False           NaN
# 189                  0.0        False   False     False           NaN
# 190                  0.0        False   False     False           NaN
# ...                  ...          ...     ...       ...           ...
# 25769                0.0        False   False     False           NaN
# 25883                0.0        False   False     False           NaN
# 25912                0.0        False   False     False           NaN
# 25967                6.1         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 7             18858
# 84            55882
# 189          106203
# ...

# %%
df[(df['experience_coding'] == 2.7) & ~ (df['most_used'] == 'Scikit-learn')]
# Out:
#        experience_coding  python_user  r_user  sql_user   most_used  \
# 3                    2.7        False   False      True         NaN
# 10                   2.7         True    True      True         NaN
# 67                   2.7         True   False     False  TensorFlow
# 106                  2.7        False   False      True         NaN
# 178                  2.7         True   False     False  TensorFlow
# ...                  ...          ...     ...       ...         ...
# 25638                2.7         True    True      True         NaN
# 25661                2.7         True   False     False  TensorFlow
# 25669                2.7         True   False      True  TensorFlow
# 25696                2.7         True   False     False       Keras
# 25743                2.7         True   False     False     PyTorch
#
#        compensation
# 3             62593
# 10            70564
# 67             8181
# 106           62593
# 178           59456
# ...             ...
# ...

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df['experience_coding'].min()
# Out:
# 0.0

# %%
df['compensation'].min()
# Out:
# 0

# %%
df['experience_coding'].max()
# Out:
# 30.0

# %%
df['compensation'].max()
# Out:
# 1492951

# %%
df['experience_coding'].mean()
# Out:
# 5.2974356999845975

# %%
df['compensation'].mean()
# Out:
# 53254.831818881874

# %%
df['experience_coding'].sum()
# Out:
# 137584.99999999997

# %%
df['compensation'].sum()
# Out:
# 1383134492

# %%
df['python_user'].sum()
# Out:
# 21860

# %%
df['sql_user'].sum()
# Out:
# 10757

# %%
df['r_user'].sum()
# Out:
# 5335

# %%
df.loc[df['experience_coding'] < 5, 'years'] = 'category'
data.loc[data['age'].between(20,24), 'age_group'] = 'yadult'
data.loc[data['age'].between(25,39), 'age_group'] = 'adult'
data.loc[data['age']>39, 'age_group'] = 'older_adult'

# %%
df['category'] = pd.cut(df['experience_coding'], bins=[-1, 5, 10, 15, 20, 25, float('inf')],
                       labels=['< 5 Years', '5-10 Years', '10-15 Years', '15-20 Years', '20-25 Years', '25+ Years'])

print(df)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation     category
# 0            124267   5-10 Years
# 1            236889  10-15 Years
# ...

# %%
df = pd.DataFrame(survey_data, columns=headers)
    df.to_csv(new_file.csv, index=False)

survey_data = [
    [6.1, True, False, True, 'Scikit-learn', 124267.0, '5-10 Years'],
    [12.3, True, True, True, 'Scikit-learn', 236889.0, '10-15 Years'],
    # ... other rows
]

headers = ['experience_coding', 'python_user', 'r_user', 'sql_user', 'most_used', 'compensation', 'category'] 

write_to_csv(survey_data, headers=headers)
# Out:
#   Cell In[124], line 2
#     df.to_csv(new_file.csv, index=False)
#     ^
# IndentationError: unexpected indent

# %%
df.to_csv('data.csv')
